# %% [markdown]
# <a href="https://colab.research.google.com/github/mikachan400/carisurg-portfolio-week-0/blob/main/Week0_Tutorial2_Advanced_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
"""
Week 0 - Day 2: Advanced Data Cleaning

In this notebook, multiple clinical columns including GCS, SBP, Temperature,
and pulse is cleaned using standard data cleaning techniques from a triage dataset.

"""

print("Python version:", sys.version)
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# Mount your Google Drive so files are accessible from Colab

from google.colab import drive
drive.mount('/content/drive')
print("Drive mounted successfully!")
FILE_PATH = '/content/drive/MyDrive/ColabNotebooks/EmergencyTriageDataset_Reduced_Dirty.csv'

#FILE_PATH = 'EmergencyTriageDataset_Reduced_Dirty.csv'

df = pd.read_csv(FILE_PATH)

# Re-apply Gender cleaning from Day 1 so we start from a consistent state

gender_map = {'Male': 1, 'MALE': 1, '1': 1, 'Female': 0, 'FEMALE': 0, '0': 0}
df['Gender'] = df['Gender'].map(gender_map)

print("Gender cleaned:\n")
print(df['Gender'].value_counts())
print(f"\nDataset: {df.shape[0]} rows x {df.shape[1]} columns")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted successfully!
# Gender cleaned:
#
# Gender
# 1    1176
# 0    1029
# Name: count, dtype: int64
#
# Dataset: 2205 rows x 11 columns

# %%
# Inspect before cleaning
# The five(5) useful Inspection commands

print("=== head() — first 5 rows ===")
print(df.head())

print("\n=== tail() — last 5 rows ===")
print(df.tail())

print("\n=== info() — column types ===")
df.info()

print("\n=== describe() — summary stats ===")
print(df.describe())

print("\n=== shape - (rows, columns) ===")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
# Out:
# === head() — first 5 rows ===
#    ID  Age  Gender   GCS    SBP    DBP     MAP  pulse  Temp    RR   Fio2
# 0   1   34       0  15.0   93.0   67.0   75.67  128.0  36.8  14.0   21.0
# 1   2   20       1  15.0  130.0   90.0  103.33   80.0  37.0  16.0   21.0
# 2   3   77       0  14.0  163.0  105.0  124.33   92.0  36.8  18.0   21.0
# 3   4   23       0   8.0  100.0   60.0   73.33  100.0  37.0  12.0  100.0
# 4   5   86       0  15.0  150.0   90.0  110.00   85.0  37.0  19.0   21.0
#
# === tail() — last 5 rows ===
#         ID  Age  Gender   GCS    SBP    DBP     MAP  pulse  Temp    RR  Fio2
# 2200  2380   65       1  14.0  170.0   50.0   90.00   65.0  37.0  22.0  21.0
# 2201  2381   84       0  15.0  180.0  120.0  140.00   85.0  36.1  18.0  21.0
# 2202  2382   78       0  15.0  132.0   78.0   96.00  100.0  37.9  16.0  21.0
# 2203  2383   65       1  15.0  140.0   80.0  100.00   85.0  36.4  16.0  21.0
# 2204  2384   78       0  15.0  145.0   90.0  108.33   75.0  37.6  20.0  21.0
#
# === info() — column types ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      2205 non-null   int64
#  1   Age     2205 non-null   int64
#  2   Gender  2205 non-null   int64
#  3   GCS     2205 non-null   float64
#  4   SBP     2205 non-null   float64
#  5   DBP     2183 non-null   float64
#  6   MAP     2183 non-null   float64
#  7   pulse   2205 non-null   float64
#  8   Temp    2205 non-null   float64
#  9   RR      2183 non-null   float64
#  10  Fio2    2183 non-null   float64
# dtypes: float64(8), int64(3)
# memory usage: 189.6 KB
#
# === describe() — summary stats ===
#                 ID          Age       Gender          GCS          SBP  \
# count  2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean   1154.987755    61.829478     0.533333    14.425850   126.626757
# std     677.167364    18.485363     0.499001     1.375031    26.830227
# min       1.000000    18.000000     0.000000     3.000000    55.000000
# 25%     577.000000    50.000000     0.000000    15.000000   110.000000
# 50%    1135.000000    64.000000     1.000000    15.000000   125.000000
# 75%    1703.000000    77.000000     1.000000    15.000000   140.000000
# max    2384.000000    98.000000     1.000000    15.000000   250.000000
#
#                DBP          MAP        pulse         Temp           RR  \
# count  2183.000000  2183.000000  2205.000000  2205.000000  2183.000000
# mean     77.479615    93.912277    94.326984    37.244717    20.262254
# std      16.713289    19.006296    19.881720     0.794448     5.742333
# min      30.000000    39.330000    40.000000    35.000000    12.000000
# 25%      70.000000    82.500000    80.000000    37.000000    17.000000
# 50%      78.000000    93.330000    90.000000    37.000000    18.000000
# 75%      87.000000   103.330000   106.000000    37.400000    21.000000
# max     173.000000   185.000000   170.000000    41.700000    50.000000
#
#               Fio2
# count  2183.000000
# mean     25.019698
# std      10.144288
# min      21.000000
# 25%      21.000000
# 50%      21.000000
# 75%      21.000000
# max     100.000000
#
# === shape - (rows, columns) ===
# Rows: 2205, Columns: 11

# %%
# Clean GCS
# GCS should be between 3 and 15

print("Unique GCS values:")
print(df['GCS'].unique())

print("\nMissing values before:", df['GCS'].isnull().sum())

# Convert to numeric
df['GCS'] = pd.to_numeric(df['GCS'], errors='coerce')

# Remove invalid values
df.loc[df['GCS'] < 3, 'GCS'] = np.nan
df.loc[df['GCS'] > 15, 'GCS'] = np.nan

# Fill missing values with median
df['GCS'] = df['GCS'].fillna(df['GCS'].median())

# Final check
print(df['GCS'].describe())
print("NaNs after:", df['GCS'].isnull().sum())
# Out:
# Unique GCS values:
# [15. 14.  8. 13. 12. 10.  7.  9. 11.  6.  3.]
#
# Missing values before: 0
# count    2205.000000
# mean       14.425850
# std         1.375031
# min         3.000000
# 25%        15.000000
# 50%        15.000000
# 75%        15.000000
# max        15.000000
# Name: GCS, dtype: float64
# NaNs after: 0

# %%
# Clean SBP
# SBP should be between 50 and 250 mmHg

print("Unique SBP values before:")
print(df['SBP'].unique())

# Convert to numeric
df['SBP'] = pd.to_numeric(df['SBP'], errors='coerce')

# Remove invalid values
df.loc[(df['SBP'] < 50) | (df['SBP'] > 250), 'SBP'] = np.nan

# Fill missing values with median
df['SBP'] = df['SBP'].fillna(df['SBP'].median())

print(df['SBP'].describe())
print("NaNs:", df['SBP'].isnull().sum())
# Out:
# Unique SBP values before:
# ['93' '130' '163' '100' '150' '120' '110' '153' '152' '186' '107' '80'
#  '75' '58' '140' '160' '30' '98' '90' '220' '126' '94' '124' '85' '137'
#  'error' '99' '200' '121' '127' '88' '103' '109' '193' '123' '125' '95'
#  '129' '197' '104' '115' '500' '76' '134' '106' '87' '167' '170' '176'
#  '69' '74' '113' '101' '132' '159' '119' '105' '118' '135' '122' '133'
#  '157' '190' '155' '145' '55' '158' '70' '102' '128' '89' '96' '92' '138'
#  '141' '112' '131' '117' '60' '114' '180' '172' '91' '73' '68' '151' '201'
#  '144' '185' '84' '81' '173' '161' '165' '250' '168' '82' '97' '136' '111'
#  '63' '146' '175' '116' '149' '156' '179' '210' '108' '211' '195' '178'
#  '148' '139' '164' '65' '86' '147' '142' '162' '72' '181' '143' '171'
#  '188' '166' '243' '169' '230' '226' '205' '154' '240' '203' '208' '177'
#  '183' '79' '198' '199' '77' '189']
# count    2205.000000
# mean      126.626757
# std        26.830227
# min        55.000000
# 25%       110.000000
# 50%       125.000000
# 75%       140.000000
# max       250.000000
# Name: SBP, dtype: float64
# NaNs: 0

# %%
# Clean Temperature
# Temperature should be between 32 and 43°C

def to_celsius(val):
    if pd.isnull(val):
        return np.nan
    val = str(val).replace('C', '').strip()
    try:
        return float(val)
    except:
        return np.nan

print("Unique Temp values before:")
print(df['Temp'].unique())

df['Temp'] = df['Temp'].apply(to_celsius)

df.loc[(df['Temp'] < 32) | (df['Temp'] > 43), 'Temp'] = np.nan

df['Temp'] = df['Temp'].fillna(df['Temp'].median())

print(df['Temp'].describe())
print("NaNs:", df['Temp'].isnull().sum())
# Out:
# Unique Temp values before:
# ['36.8' '37.0' '36.5' '39.0' '37.3' '36.7' '37.8' '38.5' '38.0' '37.6'
#  '38.2' '37C' '36.2' '37.2' '37.5' nan '36.9' '39.6' '37.4' '50' '40.0'
#  '39.5' '36.0' '36.1' '37.9' '36.6' '36.3' '38.7' '38.8' '37.7' '40.2'
#  '35.9' '39.2' '39.4' '36.4' '37.1' '35.0' '38.3' '38.9' '39.8' '95F'
#  '41.7' '35.5' '38.6' '39.3' '40.5' '38.4' '40.3' '38.1' '39.9']
# count    2205.000000
# mean       37.244717
# std         0.794448
# min        35.000000
# 25%        37.000000
# 50%        37.000000
# 75%        37.400000
# max        41.700000
# Name: Temp, dtype: float64
# NaNs: 0

# %%
# Chosen column
# Clean Pulse
# Pulse should be between 20 and 250 bpm

print("Unique pulse values before:")
print(df['pulse'].unique())

# Convert to numeric
df['pulse'] = pd.to_numeric(df['pulse'], errors='coerce')

# Remove invalid values
df.loc[(df['pulse'] < 20) | (df['pulse'] > 250), 'pulse'] = np.nan

# Fill missing values with median
df['pulse'] = df['pulse'].fillna(df['pulse'].median())

print(df['pulse'].describe())
print("NaNs:", df['pulse'].isnull().sum())
# Out:
# Unique pulse values before:
# [128.  80.  92. 100.  85.  99.  78. 130.  63.  98.  76. 166. 151.  94.
#   87.  75.  88. 108. 112. 125.  65.  90.  72.  58. 140. 105. 110.  97.
#   82.  84.  86.  56.  70.  69. 120. 111. 156.  60.  95. 115.  68. 104.
#  109.  67.  55. 119. 102. 129. 118.  96.  91. 122.  54. 114.  41.  89.
#  136.  79. 145. 134.  48. 155. 121. 170. 137. 101. 107. 144.  93. 106.
#   73.  77. 142. 126. 116.  50. 124. 133. 132.  74. 150. 139.  62. 160.
#  103.  52.  40. 117.  61. 113.  53.  83.  42. 138. 135.  66.  81.  64.
#  123.  59.  57.  49. 131. 147. 127.  71. 141. 162. 165.  45. 146.  51.
#  148.]
# count    2205.000000
# mean       94.326984
# std        19.881720
# min        40.000000
# 25%        80.000000
# 50%        90.000000
# 75%       106.000000
# max       170.000000
# Name: pulse, dtype: float64
# NaNs: 0

# %%
df.head()
# Out:
#    ID  Age  Gender   GCS  SBP    DBP     MAP  pulse  Temp    RR   Fio2
# 0   1   34       0  15.0   93   67.0   75.67  128.0  36.8  14.0   21.0
# 1   2   20       1  15.0  130   90.0  103.33   80.0  37.0  16.0   21.0
# 2   3   77       0  14.0  163  105.0  124.33   92.0  36.8  18.0   21.0
# 3   4   23       0   8.0  100   60.0   73.33  100.0  37.0  12.0  100.0
# 4   5   86       0  15.0  150   90.0  110.00   85.0  37.0  19.0   21.0
